# %% [markdown]
# ## Analysis of NBA Statistics and Player Salary - MVP

# %% [markdown]
# The purpose of this project is to determine what features have the largest impact when predicting the salary of an NBA Player. Below is a jointplot depicting a regression model with average points per game with annual salary.

# %% [markdown]
# ![POINTS-SALARY-3.png](attachment:POINTS-SALARY-3.png)

# %% [markdown]
# This was the first step to begin looking at important features and there seems to be a linear relationship with an r^2 of .407. The figrue depicts the actual data points while the line represents predictive values.

# %% [markdown]
# #### Next Steps

# %% [markdown]
# One of the features I plan to use is player position, so my immediate next step is to create dummy variables for this feature so it can be included in my model. Additionally, at first glance there are a few of my features that are positively correlated with eachother, so I will need to calculate VIF's to see the impact of these correlations and whether some features need to be removed.
#
# Once completed I then will attempt to cross validate my data to ensure my model is not overfit to my data. Considering there are some important features that have correlations with each other I anticipate performing a ridge regression to account for that.
#
# Lastly, once I have gotten my model to this point I will see if I can improve my model with feature engineering and/or assumption testing.
